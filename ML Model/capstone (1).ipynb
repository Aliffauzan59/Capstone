# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.models import Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPool2D
from sklearn.model_selection import train_test_split
import pickle
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
os.listdir('/content/gdrive/MyDrive/capstone')
# Out:
# ['cataract', 'normal eyes']

# %%
print('total cataract images :', len(os.listdir('/content/gdrive/MyDrive/capstone/cataract')))
print('total normal images :', len(os.listdir('/content/gdrive/MyDrive/capstone/normal eyes')))
# Out:
# total cataract images : 32
# total normal images : 108

# %%
base_dir = '/content/gdrive/MyDrive/capstone'
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.1) # set validation split
test_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range = 0.2,
    fill_mode = 'nearest',
    validation_split=0.4)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_generator = train_datagen.flow_from_directory(
    base_dir,
    target_size=(150, 150),
    batch_size=4,
    class_mode='binary',
    subset='training')
validation_generator = train_datagen.flow_from_directory(
    base_dir,
    target_size=(150, 150),
    batch_size=4,
    class_mode='binary',
    subset='validation')
# Out:
# Found 127 images belonging to 2 classes.
# Found 13 images belonging to 2 classes.

# %%
import tensorflow as tf
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),  
    tf.keras.layers.Flatten(), 
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        18464
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 9,640,801
# Trainable params: 9,640,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='binary_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(
    train_generator,
    epochs=50,
    steps_per_epoch=5,
    validation_data=validation_generator,
    validation_steps=1,
    verbose=2)
# Out:
# Epoch 1/50
# 5/5 - 6s - loss: 1.1875 - accuracy: 0.6316 - val_loss: 0.7421 - val_accuracy: 0.2500 - 6s/epoch - 1s/step
# Epoch 2/50
# 5/5 - 2s - loss: 0.7531 - accuracy: 0.4000 - val_loss: 0.6623 - val_accuracy: 0.7500 - 2s/epoch - 358ms/step
# Epoch 3/50
# 5/5 - 3s - loss: 0.6387 - accuracy: 0.7000 - val_loss: 0.6325 - val_accuracy: 0.7500 - 3s/epoch - 690ms/step
# Epoch 4/50
# 5/5 - 3s - loss: 0.5826 - accuracy: 0.7500 - val_loss: 0.5674 - val_accuracy: 1.0000 - 3s/epoch - 696ms/step
# Epoch 5/50
# 5/5 - 2s - loss: 0.4820 - accuracy: 0.8000 - val_loss: 0.5466 - val_accuracy: 0.7500 - 2s/epoch - 408ms/step
# Epoch 6/50
# 5/5 - 2s - loss: 0.4761 - accuracy: 0.8000 - val_loss: 0.5601 - val_accuracy: 1.0000 - 2s/epoch - 429ms/step
# Epoch 7/50
# 5/5 - 2s - loss: 0.5308 - accuracy: 0.8000 - val_loss: 0.5780 - val_accuracy: 0.7500 - 2s/epoch - 485ms/step
# Epoch 8/50
# 5/5 - 2s - loss: 0.4961 - accuracy: 0.8421 - val_loss: 0.7807 - val_accuracy: 0.5000 - 2s/epoch - 338ms/step
# Epoch 9/50
# 5/5 - 2s - loss: 0.6333 - accuracy: 0.7500 - val_loss: 0.5745 - val_accuracy: 1.0000 - 2s/epoch - 351ms/step
# Epoch 10/50
# 5/5 - 2s - loss: 0.4593 - accuracy: 0.7895 - val_loss: 0.5288 - val_accuracy: 0.7500 - 2s/epoch - 490ms/step
# Epoch 11/50
# 5/5 - 2s - loss: 0.3442 - accuracy: 0.9000 - val_loss: 0.4781 - val_accuracy: 0.7500 - 2s/epoch - 407ms/step
# Epoch 12/50
# 5/5 - 2s - loss: 0.2896 - accuracy: 0.9000 - val_loss: 0.2019 - val_accuracy: 1.0000 - 2s/epoch - 411ms/step
# Epoch 13/50
# 5/5 - 2s - loss: 0.3348 - accuracy: 0.8421 - val_loss: 0.9592 - val_accuracy: 0.5000 - 2s/epoch - 354ms/step
# Epoch 14/50
# 5/5 - 2s - loss: 0.3816 - accuracy: 0.7500 - val_loss: 0.2525 - val_accuracy: 1.0000 - 2s/epoch - 357ms/step
# Epoch 15/50
# 5/5 - 2s - loss: 0.1266 - accuracy: 0.9500 - val_loss: 0.2628 - val_accuracy: 0.7500 - 2s/epoch - 364ms/step
# Epoch 16/50
# 5/5 - 2s - loss: 0.2719 - accuracy: 0.9000 - val_loss: 0.2358 - val_accuracy: 1.0000 - 2s/epoch - 361ms/step
# Epoch 17/50
# 5/5 - 2s - loss: 0.0757 - accuracy: 0.9500 - val_loss: 0.1412 - val_accuracy: 1.0000 - 2s/epoch - 360ms/step
# Epoch 18/50
# 5/5 - 2s - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.7500 - 2s/epoch - 359ms/step
# Epoch 19/50
# 5/5 - 2s - loss: 0.0932 - accuracy: 0.9500 - val_loss: 0.0167 - val_accuracy: 1.0000 - 2s/epoch - 359ms/step
# Epoch 20/50
# 5/5 - 2s - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.3350 - val_accuracy: 0.7500 - 2s/epoch - 356ms/step
# Epoch 21/50
# 5/5 - 2s - loss: 0.2634 - accuracy: 0.9500 - val_loss: 0.0688 - val_accuracy: 1.0000 - 2s/epoch - 350ms/step
# Epoch 22/50
# 5/5 - 2s - loss: 0.3195 - accuracy: 0.8000 - val_loss: 0.0088 - val_accuracy: 1.0000 - 2s/epoch - 361ms/step
# Epoch 23/50
# 5/5 - 2s - loss: 0.2569 - accuracy: 0.8947 - val_loss: 0.4206 - val_accuracy: 0.7500 - 2s/epoch - 343ms/step
# Epoch 24/50
# 5/5 - 2s - loss: 0.5076 - accuracy: 0.8500 - val_loss: 0.2066 - val_accuracy: 1.0000 - 2s/epoch - 394ms/step
# Epoch 25/50
# 5/5 - 2s - loss: 0.2500 - accuracy: 0.9500 - val_loss: 0.1750 - val_accuracy: 1.0000 - 2s/epoch - 356ms/step
# Epoch 26/50
# 5/5 - 2s - loss: 0.0852 - accuracy: 1.0000 - val_loss: 0.3270 - val_accuracy: 0.7500 - 2s/epoch - 349ms/step
# Epoch 27/50
# 5/5 - 2s - loss: 0.0986 - accuracy: 1.0000 - val_loss: 0.5370 - val_accuracy: 0.5000 - 2s/epoch - 359ms/step
# Epoch 28/50
# 5/5 - 2s - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000 - 2s/epoch - 358ms/step
# Epoch 29/50
# 5/5 - 2s - loss: 0.0608 - accuracy: 0.9500 - val_loss: 0.0058 - val_accuracy: 1.0000 - 2s/epoch - 358ms/step
# Epoch 30/50
# 5/5 - 2s - loss: 0.0827 - accuracy: 0.9500 - val_loss: 0.1296 - val_accuracy: 1.0000 - 2s/epoch - 355ms/step
# Epoch 31/50
# 5/5 - 2s - loss: 0.1081 - accuracy: 0.9500 - val_loss: 1.0581 - val_accuracy: 0.7500 - 2s/epoch - 357ms/step
# Epoch 32/50
# 5/5 - 2s - loss: 0.0580 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000 - 2s/epoch - 360ms/step
# Epoch 33/50
# 5/5 - 2s - loss: 0.0866 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 1.0000 - 2s/epoch - 354ms/step
# Epoch 34/50
# 5/5 - 2s - loss: 0.4698 - accuracy: 0.9000 - val_loss: 0.0228 - val_accuracy: 1.0000 - 2s/epoch - 361ms/step
# Epoch 35/50
# 5/5 - 2s - loss: 0.1660 - accuracy: 0.9474 - val_loss: 0.1719 - val_accuracy: 1.0000 - 2s/epoch - 342ms/step
# Epoch 36/50
# 5/5 - 2s - loss: 0.0582 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 1.0000 - 2s/epoch - 341ms/step
# Epoch 37/50
# 5/5 - 2s - loss: 0.0717 - accuracy: 1.0000 - val_loss: 0.3400 - val_accuracy: 0.7500 - 2s/epoch - 352ms/step
# Epoch 38/50
# 5/5 - 2s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.5641 - val_accuracy: 0.5000 - 2s/epoch - 345ms/step
# Epoch 39/50
# 5/5 - 2s - loss: 0.0685 - accuracy: 0.9474 - val_loss: 0.0144 - val_accuracy: 1.0000 - 2s/epoch - 337ms/step
# Epoch 40/50
# 5/5 - 2s - loss: 0.1176 - accuracy: 0.9000 - val_loss: 0.0034 - val_accuracy: 1.0000 - 2s/epoch - 346ms/step
# Epoch 41/50
# 5/5 - 2s - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.6784 - val_accuracy: 0.5000 - 2s/epoch - 351ms/step
# Epoch 42/50
# 5/5 - 2s - loss: 0.5720 - accuracy: 0.9000 - val_loss: 0.1050 - val_accuracy: 1.0000 - 2s/epoch - 362ms/step
# Epoch 43/50
# 5/5 - 2s - loss: 0.0885 - accuracy: 0.9500 - val_loss: 0.0217 - val_accuracy: 1.0000 - 2s/epoch - 349ms/step
# Epoch 44/50
# 5/5 - 2s - loss: 0.0622 - accuracy: 1.0000 - val_loss: 0.2811 - val_accuracy: 0.7500 - 2s/epoch - 350ms/step
# Epoch 45/50
# 5/5 - 2s - loss: 0.0431 - accuracy: 1.0000 - val_loss: 0.0519 - val_accuracy: 1.0000 - 2s/epoch - 351ms/step
# Epoch 46/50
# 5/5 - 2s - loss: 0.2738 - accuracy: 0.9000 - val_loss: 0.0176 - val_accuracy: 1.0000 - 2s/epoch - 360ms/step
# Epoch 47/50
# 5/5 - 2s - loss: 0.0949 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 1.0000 - 2s/epoch - 342ms/step
# Epoch 48/50
# 5/5 - 2s - loss: 0.3033 - accuracy: 0.9500 - val_loss: 0.0187 - val_accuracy: 1.0000 - 2s/epoch - 351ms/step
# Epoch 49/50
# 5/5 - 2s - loss: 0.2154 - accuracy: 0.9474 - val_loss: 0.3424 - val_accuracy: 0.7500 - 2s/epoch - 343ms/step
# Epoch 50/50
# 5/5 - 2s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000 - 2s/epoch - 353ms/step

# %%
import matplotlib.pyplot as plt
accur = history.history['accuracy']
val_accur = history.history['val_accuracy'] 
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accur))

plt.figure()
plt.subplot(121)
plt.plot(epochs, accur, 'b', label='Training accuracy')
plt.plot(epochs, val_accur, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.subplot(122)
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(base_dir, batch_size=4)
  
  print(fn)
  if classes==0:
    print('normal')
  else:
    print('cataract')
# Out:
#      <input type="file" id="files-fac3fc7a-ae12-4b37-be6c-d439fdc1359a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fac3fc7a-ae12-4b37-be6c-d439fdc1359a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMG20211209190342.jpg to IMG20211209190342.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-5db6f014c0eb> in <module>()
#      18
#      19   images = np.vstack([x])
# ---> 20   classes = model.predict(base_dir, batch_size=4)
#      21
#      22   print(fn)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_shape.py in __getitem__(self, key)
#     904       else:
#     905         if self._v2_behavior:
# --> 906           return self._dims[key].value
#     907         else:
#     908           return self._dims[key]
#
# IndexError: list index out of range
